hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10225.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01705.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06629.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01859.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00606.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03176.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01714.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02465.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01973.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08135.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00312.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07050.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07237.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06282.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08995.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07046.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06109.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06947.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06974.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09854.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03042.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07907.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04582.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03739.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01841.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05383.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00586.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07548.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07141.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00156.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00582.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00614.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01366.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01985.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01534.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07341.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00004.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04288.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04837.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07025.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05500.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10000.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09255.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06213.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08098.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03408.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03899.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09246.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05957.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07339.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00639.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04794.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00643.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09215.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00485.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04764.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00939.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08755.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02682.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05684.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10289.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06802.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00759.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08058.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02690.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02048.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09708.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09538.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09538.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08960.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09488.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06655.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02320.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10186.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09868.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03614.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09529.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01994.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08136.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03143.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03466.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08445.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08621.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07183.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09832.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01836.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07506.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05312.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06162.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07001.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01582.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01400.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05279.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07471.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08549.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09850.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04072.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09492.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09263.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05781.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10240.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08873.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00886.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03847.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E10297.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05555.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09469.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05066.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08107.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05788.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00667.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08831.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01106.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00151.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06564.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09357.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02956.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02168.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03829.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02566.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09320.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01993.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04531.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04251.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06124.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04693.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09681.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09649.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08284.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04908.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01807.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00140.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00888.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01579.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03474.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04890.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03503.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00885.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09888.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06658.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05679.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03703.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07985.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02163.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08589.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05330.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08601.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08224.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04090.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03975.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E03939.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08092.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09286.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01159.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09113.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09369.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09946.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05921.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01635.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00238.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07802.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04829.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02181.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02730.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08613.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04320.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09126.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04752.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00541.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02156.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00798.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09756.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08668.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00183.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07686.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01241.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E09769.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E07201.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08805.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06175.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E05917.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E08915.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E00467.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06260.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06639.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E06701.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E01897.mat
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02112.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E04134.hea
# /kaggle/input/georgia-12lead-ecg-challenge-database/WFDB/E02539.hea

# %%
import numpy as np
import pandas as pd
import os
from scipy.io import loadmat
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from keras.optimizers import Adam

# %%
# Set directory
os.chdir('/kaggle/input/georgia-12lead-ecg-challenge-database/WFDB')

def read_data_using_scipy(directory):
    signal = loadmat(directory)['val'][0]
    return signal

def read_file_using_scipy(directory):
    signal = loadmat(directory)['val'][0]
    return len(signal)

def label_loading(directory1):
    directory = directory1[:-4] + '.hea'
    with open(directory, 'r') as f:
        lines = f.readlines()
        dx = lines[15].split()
        dx = dx[1].split(',')
        dx = list(map(lambda x: np.int32(x), dx))
        return dx

def select_element_from_list(x):
    return x[0]

# %%
data_directory = os.listdir('/kaggle/input/georgia-12lead-ecg-challenge-database/WFDB')
data_directory = list(filter(lambda x: x.split('.')[1] == 'mat', data_directory))

# %%
x = list(map(read_file_using_scipy, data_directory))
x = np.array(x)

df = pd.DataFrame({'Data_Directory': data_directory, 'length': x})
print(df['length'].value_counts())
df = df[df['length'] == 5000]
df.reset_index(inplace=True, drop=True)
# Out:
# length
# 5000    10292
# 2500       52
# Name: count, dtype: int64

# %%
df['Disease'] = df['Data_Directory'].apply(label_loading)
df['Number_of_Disease'] = df['Disease'].apply(len)

one_disease_only_data = df[df['Number_of_Disease'] == 1]
one_disease_only_data = one_disease_only_data.loc[:, 'Data_Directory':'Disease']
one_disease_only_data['Disease'] = one_disease_only_data['Disease'].apply(select_element_from_list)

summary_of_disease_dist = one_disease_only_data.groupby('Disease').count()['Data_Directory']
disease = summary_of_disease_dist.sort_values()[::-1][:6].index

# %%
Our_Final_dataset_Directory = pd.DataFrame()
for i in disease:
    group = one_disease_only_data.groupby('Disease').get_group(i)
    if i == 426783006:
        group.loc[:, 'Disease'] = 0
    else:
        group.loc[:, 'Disease'] = 1
    Our_Final_dataset_Directory = pd.concat([Our_Final_dataset_Directory, group])

Our_Final_dataset_Directory.reset_index(inplace=True, drop=True)
Our_Final_dataset_Directory = Our_Final_dataset_Directory.sample(frac=1, random_state=123, ignore_index=True).loc[:, ['Data_Directory', 'Disease']]

# %%
X = Our_Final_dataset_Directory['Data_Directory']
a = X.apply(read_data_using_scipy).values
Q = np.stack(a)
print(Q)
# Out:
# [[ 58  58  58 ... -92 -87 -97]
#  [-29 -29 -29 ... -43 -43 -24]
#  [126  73   9 ...  -4   9 -19]
#  ...
#  [-68 -68 -68 ... -78 -78 -92]
#  [-58 -58 -58 ... 165 151 136]
#  [-48 -48 -48 ... -14   0  14]]

# %%
y = Our_Final_dataset_Directory['Disease']
y = y.values

X_train, X_test, y_train, y_test = train_test_split(Q, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2412, 5000, 1)
# (2412,)
# (603, 5000, 1)
# (603,)

# %%
model = Sequential()
model.add(Input(shape=(5000, 1)))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

opt = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 5000, 128)      │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 5000, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,465 (806.50 KB)
#  Trainable params: 206,465 (806.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = model.fit(X_train, y_train, batch_size=32, epochs=1, validation_data=(X_test, y_test))
# Out:
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 857s 11s/step - accuracy: 0.5266 - loss: 0.6937 - val_accuracy: 0.5904 - val_loss: 0.6766

# %%
predictions = model.predict(X_test)
print(predictions)

roc_auc = roc_auc_score(y_test, predictions)
print('ROC AUC:', roc_auc)

fpr, tpr, thresholds = roc_curve(y_test, predictions)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step
# [[0.42181638]
#  [0.4520585 ]
#  [0.40002513]
#  [0.4301896 ]
#  [0.43038505]
#  [0.4142286 ]
#  [0.41807666]
#  [0.42263913]
#  [0.4306944 ]
#  [0.41147912]
#  [0.42197934]
#  [0.42310092]
#  [0.392463  ]
#  [0.42693424]
#  [0.42471156]
#  [0.4225668 ]
#  [0.4304094 ]
#  [0.41928107]
#  [0.43838927]
#  [0.42547783]
#  [0.41860566]
#  [0.434996  ]
#  [0.4284183 ]
#  [0.42410824]
#  [0.41616023]
#  [0.43439957]
#  [0.4257507 ]
#  [0.42965728]
#  [0.42664146]
#  [0.4232259 ]
#  [0.42720374]
#  [0.41490558]
#  [0.41592616]
#  [0.42446187]
#  [0.39692548]
#  [0.42238247]
#  [0.4195733 ]
#  [0.4222432 ]
#  [0.4299898 ]
#  [0.43349892]
#  [0.43659538]
#  [0.40807492]
#  [0.4267935 ]
#  [0.42437515]
#  [0.40738857]
#  [0.4234408 ]
#  [0.42508554]
#  [0.4259955 ]
#  [0.41545868]
#  [0.42177308]
#  [0.43009883]
#  [0.41719422]
#  [0.4347826 ]
#  [0.42787173]
#  [0.41979796]
#  [0.3911811 ]
#  [0.41079208]
#  [0.4455435 ]
#  [0.4317343 ]
#  [0.42706513]
#  [0.4182658 ]
#  [0.4086902 ]
#  [0.43137687]
#  [0.37860474]
#  [0.4309659 ]
#  [0.42879888]
#  [0.42752928]
#  [0.41559625]
#  [0.42469847]
#  [0.41946408]
#  [0.4156073 ]
#  [0.42901993]
#  [0.4245967 ]
#  [0.42773905]
#  [0.4312566 ]
#  [0.42723942]
#  [0.41381067]
#  [0.42985648]
#  [0.41108575]
#  [0.40610093]
#  [0.43156865]
#  [0.40116936]
#  [0.4206063 ]
#  [0.43059355]
#  [0.40382656]
#  [0.42649695]
#  [0.41989666]
#  [0.4236461 ]
#  [0.40710065]
#  [0.43258563]
#  [0.42647085]
#  [0.42511442]
#  [0.426913  ]
#  [0.42244783]
#  [0.4333426 ]
#  [0.43059278]
#  [0.43481722]
#  [0.43231216]
#  [0.43266687]
#  [0.42661655]
#  [0.4226356 ]
#  [0.38877675]
#  [0.41719225]
#  [0.42782974]
#  [0.4191934 ]
#  [0.43531996]
#  [0.41099936]
#  [0.42703283]
#  [0.40021384]
#  [0.4083954 ]
#  [0.4130275 ]
#  [0.4192845 ]
#  [0.4280593 ]
#  [0.42860577]
#  [0.4234669 ]
#  [0.40369704]
#  [0.41612944]
#  [0.41727278]
#  [0.40238363]
#  [0.4276832 ]
#  [0.42333904]
#  [0.42800766]
#  [0.40770453]
#  [0.4233227 ]
#  [0.43274817]
#  [0.41656947]
#  [0.425709  ]
#  [0.37953383]
#  [0.42584205]
#  [0.43163228]
#  [0.42274725]
#  [0.4100628 ]
#  [0.4214889 ]
#  [0.42054206]
#  [0.4239012 ]
#  [0.42487872]
#  [0.435829  ]
#  [0.41558298]
#  [0.42495307]
#  [0.41683096]
#  [0.43396863]
#  [0.4208436 ]
#  [0.4240187 ]
#  [0.41530377]
#  [0.4121415 ]
#  [0.4158213 ]
#  [0.42357984]
#  [0.43621823]
#  [0.42321512]
#  [0.41549504]
#  [0.35493222]
#  [0.39584848]
#  [0.42908987]
#  [0.4307194 ]
#  [0.42970908]
#  [0.42371002]
#  [0.43172604]
#  [0.4106669 ]
#  [0.41790447]
#  [0.41318023]
#  [0.43447524]
#  [0.41233686]
#  [0.42928153]
#  [0.4284703 ]
#  [0.42121327]
#  [0.433165  ]
#  [0.42627102]
#  [0.42605543]
#  [0.42831153]
#  [0.43004888]
#  [0.41490757]
#  [0.43173742]
#  [0.4245229 ]
#  [0.42791122]
#  [0.42730725]
#  [0.42500216]
#  [0.42785227]
#  [0.42894146]
#  [0.43313965]
#  [0.4367593 ]
#  [0.414642  ]
#  [0.42122248]
#  [0.39207128]
#  [0.4234141 ]
#  [0.4227605 ]
#  [0.4083658 ]
#  [0.431305  ]
#  [0.41665846]
#  [0.42544606]
#  [0.4189424 ]
#  [0.41247463]
#  [0.4343488 ]
#  [0.3540549 ]
#  [0.41984782]
#  [0.4209101 ]
#  [0.4142991 ]
#  [0.41065165]
#  [0.4136903 ]
#  [0.42870992]
#  [0.4272544 ]
#  [0.42716357]
#  [0.4317076 ]
#  [0.41869012]
#  [0.4497331 ]
#  [0.42811832]
#  [0.44323474]
#  [0.4188979 ]
#  [0.43738607]
#  [0.42526445]
#  [0.43104908]
#  [0.43557286]
#  [0.41928932]
#  [0.43101197]
#  [0.43397498]
#  [0.42513746]
#  [0.42771223]
#  [0.4258853 ]
#  [0.43227777]
#  [0.40935132]
#  [0.38791707]
#  [0.42650852]
#  [0.40500578]
#  [0.43659493]
#  [0.4151239 ]
#  [0.42945182]
#  [0.43207324]
#  [0.41888478]
#  [0.40741548]
#  [0.41565114]
#  [0.41345876]
#  [0.41062927]
#  [0.429509  ]
#  [0.42325553]
#  [0.34380668]
#  [0.43069085]
#  [0.40142798]
#  [0.4301011 ]
#  [0.4372505 ]
#  [0.42544004]
#  [0.43157473]
#  [0.41997448]
#  [0.40556732]
#  [0.42624196]
#  [0.4279756 ]
#  [0.45011517]
#  [0.4205534 ]
#  [0.42476994]
#  [0.4233314 ]
#  [0.4034444 ]
#  [0.42096707]
#  [0.42004383]
#  [0.43539965]
#  [0.408805  ]
#  [0.41816378]
#  [0.43741235]
#  [0.40831524]
#  [0.42960766]
#  [0.4227537 ]
#  [0.41384858]
#  [0.38997728]
#  [0.4167915 ]
#  [0.4292127 ]
#  [0.42467922]
#  [0.42411396]
#  [0.43332806]
#  [0.4302282 ]
#  [0.40172246]
#  [0.420901  ]
#  [0.40959325]
#  [0.4251327 ]
#  [0.41563985]
#  [0.39358065]
#  [0.41709146]
#  [0.41436   ]
#  [0.4195053 ]
#  [0.40579948]
#  [0.42041248]
#  [0.42267975]
#  [0.42664966]
#  [0.42694652]
#  [0.4166456 ]
#  [0.42051545]
#  [0.4000303 ]
#  [0.40282717]
#  [0.40140405]
#  [0.4188616 ]
#  [0.43489683]
#  [0.4292622 ]
#  [0.3825276 ]
#  [0.4207934 ]
#  [0.43520933]
#  [0.42518744]
#  [0.41694835]
#  [0.43999505]
#  [0.42968732]
#  [0.4263938 ]
#  [0.4306554 ]
#  [0.4251048 ]
#  [0.41446403]
#  [0.4139037 ]
#  [0.42238918]
#  [0.4273318 ]
#  [0.4091057 ]
#  [0.4018354 ]
#  [0.43342936]
#  [0.41250014]
#  [0.42124945]
#  [0.41679394]
#  [0.40596703]
#  [0.41884977]
#  [0.42273754]
#  [0.4197021 ]
#  [0.45027307]
#  [0.42800152]
#  [0.36237925]
#  [0.42519265]
#  [0.4142447 ]
#  [0.43191823]
#  [0.39542466]
#  [0.42945355]
#  [0.430467  ]
#  [0.4384662 ]
#  [0.4208709 ]
#  [0.42649338]
#  [0.42988497]
#  [0.42929974]
#  [0.42023906]
#  [0.42697582]
#  [0.42228764]
#  [0.40959156]
#  [0.42201972]
#  [0.43389207]
#  [0.40490487]
#  [0.41619062]
#  [0.4080936 ]
#  [0.36615813]
#  [0.4350568 ]
#  [0.42124623]
#  [0.42958426]
#  [0.42780742]
#  [0.41133016]
#  [0.4204244 ]
#  [0.41487318]
#  [0.43061897]
#  [0.43330777]
#  [0.3906134 ]
#  [0.42867926]
#  [0.42203423]
#  [0.43600026]
#  [0.42860028]
#  [0.4275905 ]
#  [0.4300217 ]
#  [0.41832078]
#  [0.42228788]
#  [0.42670906]
#  [0.41779047]
#  [0.4151486 ]
#  [0.42598364]
#  [0.42444202]
#  [0.4301046 ]
#  [0.43155622]
#  [0.39742258]
#  [0.4157283 ]
#  [0.39550933]
#  [0.42577264]
#  [0.4169342 ]
#  [0.41819865]
#  [0.42583504]
#  [0.42750034]
#  [0.42680848]
#  [0.4348944 ]
#  [0.41505206]
#  [0.41983634]
#  [0.4204692 ]
#  [0.41734186]
#  [0.43018913]
#  [0.3549082 ]
#  [0.43267033]
#  [0.4183361 ]
#  [0.430199  ]
#  [0.4132716 ]
#  [0.43877134]
#  [0.42995292]
#  [0.425641  ]
#  [0.42028442]
#  [0.42966992]
#  [0.43122086]
#  [0.430526  ]
#  [0.42922303]
#  [0.40561065]
#  [0.42563975]
#  [0.3850587 ]
#  [0.40375522]
#  [0.41544425]
#  [0.42503545]
#  [0.41415462]
#  [0.42343956]
#  [0.43584108]
#  [0.4152604 ]
#  [0.42496628]
#  [0.4363361 ]
#  [0.42699078]
#  [0.41711053]
#  [0.42523763]
#  [0.43235973]
#  [0.4198809 ]
#  [0.41898063]
#  [0.40728047]
#  [0.42177126]
#  [0.41525468]
#  [0.43079787]
#  [0.3972044 ]
#  [0.42240766]
#  [0.40161228]
#  [0.42406166]
#  [0.4314674 ]
#  [0.4283288 ]
#  [0.42596936]
#  [0.3289741 ]
#  [0.42818892]
#  [0.4179177 ]
#  [0.41722083]
#  [0.43764773]
#  [0.41589332]
#  [0.43664157]
#  [0.42469972]
#  [0.42624965]
#  [0.40845016]
#  [0.41825426]
#  [0.43428937]
#  [0.4211062 ]
#  [0.4383501 ]
#  [0.4324141 ]
#  [0.42883068]
#  [0.4331975 ]
#  [0.44548866]
#  [0.4360625 ]
#  [0.39683795]
#  [0.41422585]
#  [0.43056503]
#  [0.4156254 ]
#  [0.41456488]
#  [0.4283119 ]
#  [0.4473799 ]
#  [0.42786828]
#  [0.4157975 ]
#  [0.37704384]
#  [0.36254284]
#  [0.4218579 ]
#  [0.42734644]
#  [0.44514272]
#  [0.42940623]
#  [0.40936694]
#  [0.39926326]
#  [0.425949  ]
#  [0.44888097]
#  [0.412598  ]
#  [0.4193996 ]
#  [0.42037183]
#  [0.42997417]]
# ROC AUC: 0.530625938224992

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from sklearn.metrics import confusion_matrix, roc_curve, auc
# Binarize predictions
binary_predictions = (predictions > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, binary_predictions)
print('Confusion Matrix:')
print(cm)

# Plot Confusion Matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[356   0]
#  [247   0]]
